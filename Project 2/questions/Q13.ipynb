# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
pdDf = pd.read_csv('NetflixOriginals.csv', encoding='latin-1')

# %%
pdDf["Date"] = pd.to_datetime(pdDf.Premiere)

# %%
pdDf['Year'] = pdDf['Date'].dt.year
pdDf['Year'].value_counts(sort=True)[0:1]
year = pdDf['Year'].value_counts(sort=True)

# %%
pdDf.groupby("Year").agg({"Runtime": "sum"}).sort_values(by="Runtime", ascending=False)[0:1]
# Out:
#       Runtime
# Year
# 2020    17384
